# %% [markdown]
# Model Integration with OpenAI, Google Gemini and Groq

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

models = init_chat_model(model="gpt-4.1-nano")
models
# Out:
# ChatOpenAI(profile={'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x1124e0950>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x112b62690>, root_client=<openai.OpenAI object at 0x112107d90>, root_async_client=<openai.AsyncOpenAI object at 0x112b621d0>, model_name='gpt-4.1-nano', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %% [markdown]
# invoke the model

# %%
models.invoke("hi").content
# Out:
# 'Hello! How can I assist you today?'

# %% [markdown]
# ### Google chat model

# %%
model_gemini = init_chat_model("google_genai:gemini-3-flash-preview")
###  or use vertex ai
model_gemini
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-3-flash-preview', temperature=1.0, client=<google.genai.client.Client object at 0x1164df350>, default_metadata=(), model_kwargs={})

# %%
model_gemini.invoke("Why are jews so hated")
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The hatred of Jewish people, known as **antisemitism**, is often referred to by historians as "the longest hatred." It is a complex phenomenon that has evolved over thousands of years, shifting from religious prejudice to racial biological hatred and, more recently, to political and conspiratorial tropes.\n\nThere is no single reason for antisemitism; rather, it is a combination of several historical, religious, and social factors that have built upon one another.\n\n### 1. Religious Origins (Anti-Judaism)\nThe roots of antisemitism in the Western world are largely tied to the early history of Christianity.\n*   **The "Deicide" Charge:** For centuries, a primary source of hatred was the accusation that Jews were collectively responsible for the death of Jesus Christ. This "deicide" charge was used to justify persecution and remained official Catholic teaching until the 1960s (Vatican II).\n*   **The "Old" vs. "New" Covenant:** As Christian
# ...

# %% [markdown]
# Another way

# %%
###Chat openAi
from langchain_openai import ChatOpenAI
modelOpenAI = ChatOpenAI(model="gpt-4.1-nano")
response = modelOpenAI.invoke("whats today's date?")

# %%
response
# Out:
# AIMessage(content="Today's date is October 27, 2023.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 12, 'total_tokens': 23, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_336de151a4', 'id': 'chatcmpl-DF2CAdRoVaGWexixH6dhPVZy1zRNZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cafc9-478d-72e3-b6de-9b9e4858a3f3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 11, 'total_tokens': 23, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

modelGoogleGenAi = ChatGoogleGenerativeAI(model='gemini-3-flash-preview')
response = modelGoogleGenAi.invoke("hello ")

# %%
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Hello! How can I help you today?', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cafca-60c8-78c1-93fe-75557aa8e865-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3, 'output_tokens': 73, 'total_tokens': 76, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}})

# %% [markdown]
# ### GROQ model
