# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# Text Prompts -> ideal for straight forward generation tasks where we don't need to retain history
# <br>This is single standalone request
# <br>we don't need conversation history
# <br> Minimal code complexity

# %%
model.invoke("what is water")

# %% [markdown]
# Check notion

# %% [markdown]
# Pydantic

# %%
from langchain.chat_models import init_chat_model


model = init_chat_model(model='gpt-4.1-nano')

# %%
from pydantic import BaseModel, Field

class Actor(BaseModel):
    name:str
    role:str

class Movie(BaseModel):
    title:str
    year:str
    actors:list[Actor]
    genres: list[str]
    budget: float|None = Field(None,description="Budget in Million USD")
    
    
model_with_structure = model.with_structured_output(Movie)

# %%
response = model_with_structure.invoke("Tell me about intersteller")
response
# Out:
# /Users/kshitizraj/Desktop/Development/langchain/.venv/lib/python3.11/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=Movie(title='Interstellar... 'Drama'], budget=165.0), input_type=Movie])
#   return self.__pydantic_serializer__.to_python(
# Movie(title='Interstellar', year='2014', actors=[Actor(name='Matthew McConaughey', role='Joseph Cooper'), Actor(name='Anne Hathaway', role='Dr. Brand'), Actor(name='Jessica Chastain', role='Murph Cooper'), Actor(name='Michael Caine', role='Professor Brand')], genres=['Sci-Fi', 'Adventure', 'Drama'], budget=165.0)
